# %%
import requests
import json
from datetime import datetime
import time
import re
import os

#Paste your user_id and session_id in quotes on the right lines.
#make sure session id is only the id, not the stuff at the end and without 'tavern-keeper=' at the start.
session_id = ""
user_id = ""

timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
export_dir = f"export_data_{timestamp}"
sleep_delay = 0.5


def get_tk_data(req, paged_type=None):
    host = r"https://www.tavern-keeper.com"
    url = host + req
    
    headers = {
        "Accept" : r"application/json",
        'Content-Type': 'application/json',
        "cookie" : f"tavern-keeper={session_id}",
        "X-CSRF-Token" : "something"
    }
    
    outdata = []  # List to hold paged data
    page = 1  # Start with the first page
    
    if paged_type:
        # print ('data type is paged')
        while True:
            paginated_url = f"{url}?page={page}"
            time.sleep(0.5)
            response = requests.get(paginated_url, headers=headers)
            # print(response.url)
            if response.status_code == 200:
                pagedata = response.json()  
                
                # Append data from the current page to the list
                outdata.extend(pagedata.get(paged_type, []))
    
                # Check if there are more pages
                if page >= pagedata.get("pages", 1):
                    break  # Exit the loop if we've reached the last page
    
                page += 1  # Move to the next page
                # print(f"paging page{page}")
            else:
                print("Failed to fetch campaigns. Status code:", response.status_code)
                break
    else:
        print(f"Request URL is {url}")
        response = requests.get(url, headers=headers)
        if response.status_code == 200:
            outdata= response.json()
        else:
            print("Failed to fetch campaigns. Status code:", response.status_code)
    return outdata


def write_outfile(data, filename, subpath=None):
    global export_dir
    out_dir = export_dir
    if subpath: 
        out_dir = "/".join([export_dir,subpath])
    if not os.path.exists(out_dir):
        os.makedirs(out_dir)
    filename = sanitize_filename(filename)
    path = os.path.join(out_dir, filename)
    print(f"export path is: {path}")
    with open(path, 'w') as file:
        json.dump(data, file, indent=4)
    print(f"Data saved.")


def sanitize_filename(filename):
    # Define a regex pattern to match illegal characters
    legal_pattern = r'[^\w\-.]'
    # Replace illegal characters with an underscore
    sanitized_filename = re.sub(legal_pattern, '_', filename)
    
    # Remove all dashes
    filename = sanitized_filename.replace('-', '')
    # Remove double underscores
    filename = re.sub(r'__+', '_', filename)
    # Remove periods followed by underscores
    filename = re.sub(r'\._+', '.', filename)
    return filename


def get_tk_campaigns(user_id):
    campaign_list = get_campaign_list(user_id)
    # for cam in campaign_list[:1]:
    for cam in campaign_list:
        cid, cname = cam
        get_campaign(cid, cname)
    print("All campaigns downloaded. Process complete")
    return campaign_list
    

def get_campaign_list(user_id):
    req = fr"/api_v0/users/{user_id}/campaigns"
    cam_data = get_tk_data(req)
    filename = f"index_campaign_list_user_{user_id}.json"
    write_outfile(cam_data, filename)
    return [(cam['id'], cam['name']) for cam in cam_data['campaigns']]
              

def get_campaign(cid, cname):
    cam_subpath = sanitize_filename("_".join([str(cid), cname]))
    rp_list = get_roleplay_list(cid, cname, cam_subpath)
    dis_list = get_discussion_list(cid, cname, cam_subpath)
    for rpid in rp_list:
    # for rpid in rp_list[:5]:       
        print(f"Getting roleplay {rpid} for campaign {cid}.")
        get_roleplay(rpid, cam_subpath)
    print("Roleplays Complete")
    for did in dis_list:
    # for did in dis_list[:5]:
        print(f"Getting discussion {did} for campaign {cid}")
        get_discussion(did, cid, cam_subpath)
    print(f"Campaign {cid} complete")
    # return rp_list
    # return rp_data


def get_character_list(uid):
    req_char = f'/api_v0/users/{uid}/characters'
    char_lists = [get_tk_data(req_char, 'characters'),
                  get_tk_data(req_char + "?archived=true", 'characters')
                 ]
    char_list = char_lists[0] + char_lists[1]
    filename = f"index_char_list_user_{user_id}.json"
    write_outfile(char_list, filename, "characters")
    return [[char['id'] for char in char_list], 
            [char['name'] for char in char_list]
           ]

def get_tk_characters(uid):
    list_char_id, list_char_nm = get_character_list(uid)
    for char in zip(list_char_id, list_char_nm):
        cid, name = char
        print(f"Fetching character {cid} {name}")
        req = f'/api_v0/characters/{cid}'
        char_data = get_tk_data(req)
        if not char_data:
            continue
        dirname = sanitize_filename(f"{cid}_{name}")
        char_subpath = f"characters/{dirname}"
        filename = dirname + ".json"
        write_outfile(char_data, filename, char_subpath)

        portrait_url = char_data['image_url']
        if portrait_url:
            r = requests.get(portrait_url, stream=True)
            if r.status_code !=200:
                print(r.status_code, 'portrait download failed')
                continue
            path_portrait = os.path.join(export_dir + "/" + char_subpath, dirname + ".jpg")
            with open(path_portrait, 'wb') as f:
                for chunk in r:
                    f.write(chunk)
        else:
            print("No portrait url.")
    print("Character download is complete.")
        
        
def get_roleplay_list(cid, cname, cam_path):
    cam_path = cam_path + "/roleplays"
    print(f'Fetching roleplay list for campaign {cid}.')
    req = fr"/api_v0/campaigns/{cid}/roleplays"
    rp_data = get_tk_data(req, 'roleplays')
    filename = f"index_roleplay_list_campaign_{cid}_{cname}.json"
    write_outfile(rp_data, filename, cam_path)
    return [rp['id'] for rp in rp_data]


def get_discussion_list(cid, cname, cam_path):
    cam_path = cam_path + "/discussions"
    print(f'Fetching discussion list for campaign {cid}.')
    req = fr"/api_v0/campaigns/{cid}/discussions"
    dis_data = get_tk_data(req, 'discussions')
    filename = f"index_discussion_list_campaign_{cid}_{cname}.json"
    write_outfile(dis_data, filename, cam_path)
    return [dis['id'] for dis in dis_data]


def get_discussion(did, cid, cam_path):
    cam_path = cam_path + "/discussions"
    req_dis_data = fr'/api_v0/campaigns/{cid}/discussions/{did}'
    req_dis_comm = fr'/api_v0/campaigns/{cid}/discussions/{did}/comments'
    dis_data = get_tk_data(req_dis_data)
    dis_comm = get_tk_data(req_dis_comm, 'comments')
    dis_data['comments'] = dis_comm
    fname = f"discussion_{did}_{dis_data['name']}.json"
    write_outfile(dis_data, fname, cam_path)
    return dis_data
    

def get_roleplay(rid, cam_path):
    cam_path = cam_path + "/roleplays"
    req_rp_data = fr"/api_v0/roleplays/{rid}"
    req_rp_msgs = fr"/api_v0/roleplays/{rid}/messages"
    print("Getting Scene Data") 
    rp_data = get_tk_data(req_rp_data)
    print("Getting Message Data")
    rp_msgs = get_tk_data(req_rp_msgs, 'messages')
    rp_data['messages'] = rp_msgs
    print("Fetching Comments for Messages")
    for msg in rp_data['messages']:
        if msg['comment_count'] > 0:
            mid = str(msg['id'])
            req = fr'/api_v0/roleplays/{rid}/messages/{mid}/comments'
            comments = get_tk_data(req, 'comments')
            msg['comments'] = comments
    fname = f"roleplay_{rid}_{rp_data['name']}.json"
    write_outfile(rp_data, fname, cam_path)
    return rp_data


get_tk_characters(user_id)
get_tk_campaigns(user_id)
# Out:
# export path is: export_data_20250427_194352/characters\index_char_list_user_1398.json
# Data saved.
# Fetching character 3366 Agent Dorothy "Dot" Munroe
# Request URL is https://www.tavern-keeper.com/api_v0/characters/3366
# export path is: export_data_20250427_194352/characters/3366_Agent_Dorothy_Dot_Munroe\3366_Agent_Dorothy_Dot_Munroe.json
# Data saved.
# Fetching character 28904 Aletheia “Alleycat” Kathan
# Request URL is https://www.tavern-keeper.com/api_v0/characters/28904
# export path is: export_data_20250427_194352/characters/28904_Aletheia_Alleycat_Kathan\28904_Aletheia_Alleycat_Kathan.json
# Data saved.
# Fetching character 3105 Andy Jaeger
# Request URL is https://www.tavern-keeper.com/api_v0/characters/3105
# export path is: export_data_20250427_194352/characters/3105_Andy_Jaeger\3105_Andy_Jaeger.json
# Data saved.
# Fetching character 2961 Aquamarine
# Request URL is https://www.tavern-keeper.com/api_v0/characters/2961
# export path is: export_data_20250427_194352/characters/2961_Aquamarine\2961_Aquamarine.json
# Data saved.
# Fetching character 3107 Brian Lindon
# Request URL is https://www.tavern-keeper.com/api_v0/characters/3107
# export path is: export_data_20250427_194352/characters/3107_Brian_Lindon\3107_Brian_Lindon.json
# Data saved.
# Fetching character 30962 Coral Corrupción (Cora)
# Request URL is https://www.tavern-keeper.com/api_v0/characters/30962
# export path is: export_data_20250427_194352/characters/30962_Coral_Corrupción_Cora_\30962_Coral_Corrupción_Cora_.json
# Data saved.
# Fetching character 25229 Daemon
# Request URL is https://www.tavern-keeper.com/api_v0/characters/25229
# export path is: export_data_20250427_194352/characters/25229_Daemon\25229_Daemon.json
# Data saved.
# Fetching character 3301 Det Henry "Hank" Louis
# Request URL is https://www.tavern-keeper.com/api_v0/characters/3301
# export path is: export_data_20250427_194352/characters/3301_Det_Henry_Hank_Louis\3301_Det_Henry_Hank_Louis.json
# Data saved.
# Fetching character 3069 Dremmer
# Request URL is https://www.tavern-keeper.com/api_v0/characters/3069
# export path is: export_data_20250427_194352/characters/3069_Dremmer\3069_Dremmer.json
# Data saved.
# Fetching character 26039 Dr. Faith Jackson
# Request URL is https://www.tavern-keeper.com/api_v0/characters/26039
# export path is: export_data_20250427_194352/characters/26039_Dr.Faith_Jackson\26039_Dr.Faith_Jackson.json
# Data saved.
# Fetching character 8766 Dr. Persephone Horne
# Request URL is https://www.tavern-keeper.com/api_v0/characters/8766
# export path is: export_data_20250427_194352/characters/8766_Dr.Persephone_Horne\8766_Dr.Persephone_Horne.json
# Data saved.
# Fetching character 2999 Elsurikkar, demon
# Request URL is https://www.tavern-keeper.com/api_v0/characters/2999
# export path is: export_data_20250427_194352/characters/2999_Elsurikkar_demon\2999_Elsurikkar_demon.json
# Data saved.
# Fetching character 2685 Enough-to-Eat
# Request URL is https://www.tavern-keeper.com/api_v0/characters/2685
# export path is: export_data_20250427_194352/characters/2685_EnoughtoEat\2685_EnoughtoEat.json
# Data saved.
# Fetching character 3104 Ethan Cain
# Request URL is https://www.tavern-keeper.com/api_v0/characters/3104
# export path is: export_data_20250427_194352/characters/3104_Ethan_Cain\3104_Ethan_Cain.json
# Data saved.
# Fetching character 25210 Father Salvatori (M)
# Request URL is https://www.tavern-keeper.com/api_v0/characters/25210
# export path is: export_data_20250427_194352/characters/25210_Father_Salvatori_M_\25210_Father_Salvatori_M_.json
# Data saved.
# Fetching character 2726 Fern
# Request URL is https://www.tavern-keeper.com/api_v0/characters/2726
# export path is: export_data_20250427_194352/characters/2726_Fern\2726_Fern.json
# Data saved.
# Fetching character 8376 Grem
# Request URL is https://www.tavern-keeper.com/api_v0/characters/8376
# export path is: export_data_20250427_194352/characters/8376_Grem\8376_Grem.json
# Data saved.
# Fetching character 2684 Hanrahan
# Request URL is https://www.tavern-keeper.com/api_v0/characters/2684
# export path is: export_data_20250427_194352/characters/2684_Hanrahan\2684_Hanrahan.json
# Data saved.
# Fetching character 25549 Inigo
# Request URL is https://www.tavern-keeper.com/api_v0/characters/25549
# export path is: export_data_20250427_194352/characters/25549_Inigo\25549_Inigo.json
# Data saved.
# Fetching character 2683 Isis
# Request URL is https://www.tavern-keeper.com/api_v0/characters/2683
# export path is: export_data_20250427_194352/characters/2683_Isis\2683_Isis.json
# Data saved.
# Fetching character 2702 Jubilee
# Request URL is https://www.tavern-keeper.com/api_v0/characters/2702
# export path is: export_data_20250427_194352/characters/2702_Jubilee\2702_Jubilee.json
# Data saved.
# Fetching character 24961 Kaitlin Vance
# Request URL is https://www.tavern-keeper.com/api_v0/characters/24961
# export path is: export_data_20250427_194352/characters/24961_Kaitlin_Vance\24961_Kaitlin_Vance.json
# Data saved.
# Fetching character 3064 Kimimela Red Bear
# Request URL is https://www.tavern-keeper.com/api_v0/characters/3064
# export path is: export_data_20250427_194352/characters/3064_Kimimela_Red_Bear\3064_Kimimela_Red_Bear.json
# Data saved.
# Fetching character 26536 Kyra Lancaster
# Request URL is https://www.tavern-keeper.com/api_v0/characters/26536
# export path is: export_data_20250427_194352/characters/26536_Kyra_Lancaster\26536_Kyra_Lancaster.json
# Data saved.
# Fetching character 16129 Lakshmi "Lucky" Suresh
# Request URL is https://www.tavern-keeper.com/api_v0/characters/16129
# export path is: export_data_20250427_194352/characters/16129_Lakshmi_Lucky_Suresh\16129_Lakshmi_Lucky_Suresh.json
# Data saved.
# Fetching character 2686 Lamprey
# Request URL is https://www.tavern-keeper.com/api_v0/characters/2686
# export path is: export_data_20250427_194352/characters/2686_Lamprey\2686_Lamprey.json
# Data saved.
# Fetching character 3705 Lawn
# Request URL is https://www.tavern-keeper.com/api_v0/characters/3705
# export path is: export_data_20250427_194352/characters/3705_Lawn\3705_Lawn.json
# Data saved.
# Fetching character 3822 League
# Request URL is https://www.tavern-keeper.com/api_v0/characters/3822
# export path is: export_data_20250427_194352/characters/3822_League\3822_League.json
# Data saved.
# Fetching character 24745 MC
# Request URL is https://www.tavern-keeper.com/api_v0/characters/24745
# export path is: export_data_20250427_194352/characters/24745_MC\24745_MC.json
# Data saved.
# No portrait url.
# Fetching character 3416 MC-Trevis
# Request URL is https://www.tavern-keeper.com/api_v0/characters/3416
# export path is: export_data_20250427_194352/characters/3416_MCTrevis\3416_MCTrevis.json
# Data saved.
# No portrait url.
# Fetching character 15318 Naaya Rathod
# Request URL is https://www.tavern-keeper.com/api_v0/characters/15318
# export path is: export_data_20250427_194352/characters/15318_Naaya_Rathod\15318_Naaya_Rathod.json
# Data saved.
# Fetching character 12368 Naaya Rathod
# Request URL is https://www.tavern-keeper.com/api_v0/characters/12368
# export path is: export_data_20250427_194352/characters/12368_Naaya_Rathod\12368_Naaya_Rathod.json
# Data saved.
# Fetching character 18638 Natalia Clark
# Request URL is https://www.tavern-keeper.com/api_v0/characters/18638
# export path is: export_data_20250427_194352/characters/18638_Natalia_Clark\18638_Natalia_Clark.json
# Data saved.
# Fetching character 3186 Newton
# Request URL is https://www.tavern-keeper.com/api_v0/characters/3186
# export path is: export_data_20250427_194352/characters/3186_Newton\3186_Newton.json
# Data saved.
# Fetching character 3103 Nimet Sabri
# Request URL is https://www.tavern-keeper.com/api_v0/characters/3103
# export path is: export_data_20250427_194352/characters/3103_Nimet_Sabri\3103_Nimet_Sabri.json
# Data saved.
# Fetching character 3692 Perez
# Request URL is https://www.tavern-keeper.com/api_v0/characters/3692
# export path is: export_data_20250427_194352/characters/3692_Perez\3692_Perez.json
# Data saved.
# Fetching character 30314 Rebecca Jane “RJ” Larkin
# Request URL is https://www.tavern-keeper.com/api_v0/characters/30314
# export path is: export_data_20250427_194352/characters/30314_Rebecca_Jane_RJ_Larkin\30314_Rebecca_Jane_RJ_Larkin.json
# Data saved.
# Fetching character 3399 Rhainor
# Request URL is https://www.tavern-keeper.com/api_v0/characters/3399
# export path is: export_data_20250427_194352/characters/3399_Rhainor\3399_Rhainor.json
# Data saved.
# Fetching character 2873 Rothschild
# Request URL is https://www.tavern-keeper.com/api_v0/characters/2873
# export path is: export_data_20250427_194352/characters/2873_Rothschild\2873_Rothschild.json
# Data saved.
# Fetching character 3106 Sharon Golding
# Request URL is https://www.tavern-keeper.com/api_v0/characters/3106
# export path is: export_data_20250427_194352/characters/3106_Sharon_Golding\3106_Sharon_Golding.json
# Data saved.
# Fetching character 3575 Spector
# Request URL is https://www.tavern-keeper.com/api_v0/characters/3575
# export path is: export_data_20250427_194352/characters/3575_Spector\3575_Spector.json
# Data saved.
# Fetching character 2678 Storm
# Request URL is https://www.tavern-keeper.com/api_v0/characters/2678
# export path is: export_data_20250427_194352/characters/2678_Storm\2678_Storm.json
# Data saved.
# Fetching character 24911 Templates
# Request URL is https://www.tavern-keeper.com/api_v0/characters/24911
# export path is: export_data_20250427_194352/characters/24911_Templates\24911_Templates.json
# Data saved.
# No portrait url.
# Fetching character 3000 The Perfect Score Project
# Request URL is https://www.tavern-keeper.com/api_v0/characters/3000
# export path is: export_data_20250427_194352/characters/3000_The_Perfect_Score_Project\3000_The_Perfect_Score_Project.json
# Data saved.
# Fetching character 2454 Veronica Machado
# Request URL is https://www.tavern-keeper.com/api_v0/characters/2454
# export path is: export_data_20250427_194352/characters/2454_Veronica_Machado\2454_Veronica_Machado.json
# Data saved.
# Fetching character 15926 Wolf!Naaya
# Request URL is https://www.tavern-keeper.com/api_v0/characters/15926
# export path is: export_data_20250427_194352/characters/15926_Wolf_Naaya\15926_Wolf_Naaya.json
# Data saved.
# Fetching character 13698 Wolf!Naaya
# Request URL is https://www.tavern-keeper.com/api_v0/characters/13698
# export path is: export_data_20250427_194352/characters/13698_Wolf_Naaya\13698_Wolf_Naaya.json
# Data saved.
# Fetching character 3366 Agent Dorothy "Dot" Munroe
# Request URL is https://www.tavern-keeper.com/api_v0/characters/3366
# export path is: export_data_20250427_194352/characters/3366_Agent_Dorothy_Dot_Munroe\3366_Agent_Dorothy_Dot_Munroe.json
# Data saved.
# Fetching character 28904 Aletheia “Alleycat” Kathan
# Request URL is https://www.tavern-keeper.com/api_v0/characters/28904
# export path is: export_data_20250427_194352/characters/28904_Aletheia_Alleycat_Kathan\28904_Aletheia_Alleycat_Kathan.json
# Data saved.
# Fetching character 3105 Andy Jaeger
# Request URL is https://www.tavern-keeper.com/api_v0/characters/3105
# export path is: export_data_20250427_194352/characters/3105_Andy_Jaeger\3105_Andy_Jaeger.json
# Data saved.
# Fetching character 2961 Aquamarine
# Request URL is https://www.tavern-keeper.com/api_v0/characters/2961
# export path is: export_data_20250427_194352/characters/2961_Aquamarine\2961_Aquamarine.json
# Data saved.
# Fetching character 3107 Brian Lindon
# Request URL is https://www.tavern-keeper.com/api_v0/characters/3107
# export path is: export_data_20250427_194352/characters/3107_Brian_Lindon\3107_Brian_Lindon.json
# Data saved.
# Fetching character 30962 Coral Corrupción (Cora)
# Request URL is https://www.tavern-keeper.com/api_v0/characters/30962
# export path is: export_data_20250427_194352/characters/30962_Coral_Corrupción_Cora_\30962_Coral_Corrupción_Cora_.json
# Data saved.
# Fetching character 25229 Daemon
# Request URL is https://www.tavern-keeper.com/api_v0/characters/25229
# export path is: export_data_20250427_194352/characters/25229_Daemon\25229_Daemon.json
# Data saved.
# Fetching character 3301 Det Henry "Hank" Louis
# Request URL is https://www.tavern-keeper.com/api_v0/characters/3301
# export path is: export_data_20250427_194352/characters/3301_Det_Henry_Hank_Louis\3301_Det_Henry_Hank_Louis.json
# Data saved.
# Fetching character 3069 Dremmer
# Request URL is https://www.tavern-keeper.com/api_v0/characters/3069
# export path is: export_data_20250427_194352/characters/3069_Dremmer\3069_Dremmer.json
# Data saved.
# Fetching character 26039 Dr. Faith Jackson
# Request URL is https://www.tavern-keeper.com/api_v0/characters/26039
# export path is: export_data_20250427_194352/characters/26039_Dr.Faith_Jackson\26039_Dr.Faith_Jackson.json
# Data saved.
# Fetching character 8766 Dr. Persephone Horne
# Request URL is https://www.tavern-keeper.com/api_v0/characters/8766
# export path is: export_data_20250427_194352/characters/8766_Dr.Persephone_Horne\8766_Dr.Persephone_Horne.json
# Data saved.
# Fetching character 2999 Elsurikkar, demon
# Request URL is https://www.tavern-keeper.com/api_v0/characters/2999
# export path is: export_data_20250427_194352/characters/2999_Elsurikkar_demon\2999_Elsurikkar_demon.json
# Data saved.
# Fetching character 2685 Enough-to-Eat
# Request URL is https://www.tavern-keeper.com/api_v0/characters/2685
# export path is: export_data_20250427_194352/characters/2685_EnoughtoEat\2685_EnoughtoEat.json
# Data saved.
# Fetching character 3104 Ethan Cain
# Request URL is https://www.tavern-keeper.com/api_v0/characters/3104
# export path is: export_data_20250427_194352/characters/3104_Ethan_Cain\3104_Ethan_Cain.json
# Data saved.
# Fetching character 25210 Father Salvatori (M)
# Request URL is https://www.tavern-keeper.com/api_v0/characters/25210
# export path is: export_data_20250427_194352/characters/25210_Father_Salvatori_M_\25210_Father_Salvatori_M_.json
# Data saved.
# Fetching character 2726 Fern
# Request URL is https://www.tavern-keeper.com/api_v0/characters/2726
# export path is: export_data_20250427_194352/characters/2726_Fern\2726_Fern.json
# Data saved.
# Fetching character 8376 Grem
# Request URL is https://www.tavern-keeper.com/api_v0/characters/8376
# export path is: export_data_20250427_194352/characters/8376_Grem\8376_Grem.json
# Data saved.
# Fetching character 2684 Hanrahan
# Request URL is https://www.tavern-keeper.com/api_v0/characters/2684
# export path is: export_data_20250427_194352/characters/2684_Hanrahan\2684_Hanrahan.json
# Data saved.
# Fetching character 25549 Inigo
# Request URL is https://www.tavern-keeper.com/api_v0/characters/25549
# export path is: export_data_20250427_194352/characters/25549_Inigo\25549_Inigo.json
# Data saved.
# Fetching character 2683 Isis
# Request URL is https://www.tavern-keeper.com/api_v0/characters/2683
# export path is: export_data_20250427_194352/characters/2683_Isis\2683_Isis.json
# Data saved.
# Fetching character 2702 Jubilee
# Request URL is https://www.tavern-keeper.com/api_v0/characters/2702
# export path is: export_data_20250427_194352/characters/2702_Jubilee\2702_Jubilee.json
# Data saved.
# Fetching character 24961 Kaitlin Vance
# Request URL is https://www.tavern-keeper.com/api_v0/characters/24961
# export path is: export_data_20250427_194352/characters/24961_Kaitlin_Vance\24961_Kaitlin_Vance.json
# Data saved.
# Fetching character 3064 Kimimela Red Bear
# Request URL is https://www.tavern-keeper.com/api_v0/characters/3064
# export path is: export_data_20250427_194352/characters/3064_Kimimela_Red_Bear\3064_Kimimela_Red_Bear.json
# Data saved.
# Fetching character 26536 Kyra Lancaster
# Request URL is https://www.tavern-keeper.com/api_v0/characters/26536
# export path is: export_data_20250427_194352/characters/26536_Kyra_Lancaster\26536_Kyra_Lancaster.json
# Data saved.
# Fetching character 16129 Lakshmi "Lucky" Suresh
# Request URL is https://www.tavern-keeper.com/api_v0/characters/16129
# export path is: export_data_20250427_194352/characters/16129_Lakshmi_Lucky_Suresh\16129_Lakshmi_Lucky_Suresh.json
# Data saved.
# Fetching character 2686 Lamprey
# Request URL is https://www.tavern-keeper.com/api_v0/characters/2686
# export path is: export_data_20250427_194352/characters/2686_Lamprey\2686_Lamprey.json
# Data saved.
# Fetching character 3705 Lawn
# Request URL is https://www.tavern-keeper.com/api_v0/characters/3705
# export path is: export_data_20250427_194352/characters/3705_Lawn\3705_Lawn.json
# Data saved.
# Fetching character 3822 League
# Request URL is https://www.tavern-keeper.com/api_v0/characters/3822
# export path is: export_data_20250427_194352/characters/3822_League\3822_League.json
# Data saved.
# Fetching character 24745 MC
# Request URL is https://www.tavern-keeper.com/api_v0/characters/24745
# export path is: export_data_20250427_194352/characters/24745_MC\24745_MC.json
# Data saved.
# No portrait url.
# Fetching character 3416 MC-Trevis
# Request URL is https://www.tavern-keeper.com/api_v0/characters/3416
# export path is: export_data_20250427_194352/characters/3416_MCTrevis\3416_MCTrevis.json
# Data saved.
# No portrait url.
# Fetching character 15318 Naaya Rathod
# Request URL is https://www.tavern-keeper.com/api_v0/characters/15318
# export path is: export_data_20250427_194352/characters/15318_Naaya_Rathod\15318_Naaya_Rathod.json
# Data saved.
# Fetching character 12368 Naaya Rathod
# Request URL is https://www.tavern-keeper.com/api_v0/characters/12368
# export path is: export_data_20250427_194352/characters/12368_Naaya_Rathod\12368_Naaya_Rathod.json
# Data saved.
# Fetching character 18638 Natalia Clark
# Request URL is https://www.tavern-keeper.com/api_v0/characters/18638
# export path is: export_data_20250427_194352/characters/18638_Natalia_Clark\18638_Natalia_Clark.json
# Data saved.
# Fetching character 3186 Newton
# Request URL is https://www.tavern-keeper.com/api_v0/characters/3186
# export path is: export_data_20250427_194352/characters/3186_Newton\3186_Newton.json
# Data saved.
# Fetching character 3103 Nimet Sabri
# Request URL is https://www.tavern-keeper.com/api_v0/characters/3103
# export path is: export_data_20250427_194352/characters/3103_Nimet_Sabri\3103_Nimet_Sabri.json
# Data saved.
# Fetching character 3692 Perez
# Request URL is https://www.tavern-keeper.com/api_v0/characters/3692
# export path is: export_data_20250427_194352/characters/3692_Perez\3692_Perez.json
# Data saved.
# Fetching character 30314 Rebecca Jane “RJ” Larkin
# Request URL is https://www.tavern-keeper.com/api_v0/characters/30314
# export path is: export_data_20250427_194352/characters/30314_Rebecca_Jane_RJ_Larkin\30314_Rebecca_Jane_RJ_Larkin.json
# Data saved.
# Fetching character 3399 Rhainor
# Request URL is https://www.tavern-keeper.com/api_v0/characters/3399
# export path is: export_data_20250427_194352/characters/3399_Rhainor\3399_Rhainor.json
# Data saved.
# Fetching character 2873 Rothschild
# Request URL is https://www.tavern-keeper.com/api_v0/characters/2873
# export path is: export_data_20250427_194352/characters/2873_Rothschild\2873_Rothschild.json
# Data saved.
# Fetching character 3106 Sharon Golding
# Request URL is https://www.tavern-keeper.com/api_v0/characters/3106
# export path is: export_data_20250427_194352/characters/3106_Sharon_Golding\3106_Sharon_Golding.json
# Data saved.
# Fetching character 3575 Spector
# Request URL is https://www.tavern-keeper.com/api_v0/characters/3575
# export path is: export_data_20250427_194352/characters/3575_Spector\3575_Spector.json
# Data saved.
# Fetching character 2678 Storm
# Request URL is https://www.tavern-keeper.com/api_v0/characters/2678
# export path is: export_data_20250427_194352/characters/2678_Storm\2678_Storm.json
# Data saved.
# Fetching character 24911 Templates
# Request URL is https://www.tavern-keeper.com/api_v0/characters/24911
# export path is: export_data_20250427_194352/characters/24911_Templates\24911_Templates.json
# Data saved.
# No portrait url.
# Fetching character 3000 The Perfect Score Project
# Request URL is https://www.tavern-keeper.com/api_v0/characters/3000
# export path is: export_data_20250427_194352/characters/3000_The_Perfect_Score_Project\3000_The_Perfect_Score_Project.json
# Data saved.
# Fetching character 2454 Veronica Machado
# Request URL is https://www.tavern-keeper.com/api_v0/characters/2454
# export path is: export_data_20250427_194352/characters/2454_Veronica_Machado\2454_Veronica_Machado.json
# Data saved.
# Fetching character 15926 Wolf!Naaya
# Request URL is https://www.tavern-keeper.com/api_v0/characters/15926
# export path is: export_data_20250427_194352/characters/15926_Wolf_Naaya\15926_Wolf_Naaya.json
# Data saved.
# Fetching character 13698 Wolf!Naaya
# Request URL is https://www.tavern-keeper.com/api_v0/characters/13698
# export path is: export_data_20250427_194352/characters/13698_Wolf_Naaya\13698_Wolf_Naaya.json
# Data saved.
# Request URL is https://www.tavern-keeper.com/api_v0/users/1398/campaigns
# export path is: export_data_20250427_194352\index_campaign_list_user_1398.json
# Data saved.
# Fetching roleplay list for campaign 1660.
# export path is: export_data_20250427_194352/1660_Uncharted_Worlds_Free_Trader/roleplays\index_roleplay_list_campaign_1660_Uncharted_Worlds_Free_Trader.json
# Data saved.
# Fetching discussion list for campaign 1660.
# export path is: export_data_20250427_194352/1660_Uncharted_Worlds_Free_Trader/discussions\index_discussion_list_campaign_1660_Uncharted_Worlds_Free_Trader.json
# Data saved.
# Getting roleplay 10134 for campaign 1660.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/10134
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/1660_Uncharted_Worlds_Free_Trader/roleplays\roleplay_10134_13.X_GM_resigning.json
# Data saved.
# Getting roleplay 9800 for campaign 1660.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/9800
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/1660_Uncharted_Worlds_Free_Trader/roleplays\roleplay_9800_13a.Kiril_Extract_Edmund_Barrus_Alicia.json
# Data saved.
# Getting roleplay 9801 for campaign 1660.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/9801
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/1660_Uncharted_Worlds_Free_Trader/roleplays\roleplay_9801_13b.Kiril_Extract_Lirael.json
# Data saved.
# Getting roleplay 9834 for campaign 1660.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/9834
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/1660_Uncharted_Worlds_Free_Trader/roleplays\roleplay_9834_12a_Sunny_What_happens_in_space_stays_in_space.json
# Data saved.
# Getting roleplay 9670 for campaign 1660.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/9670
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/1660_Uncharted_Worlds_Free_Trader/roleplays\roleplay_9670_13.Kiril_Extract.json
# Data saved.
# Getting roleplay 9030 for campaign 1660.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/9030
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/1660_Uncharted_Worlds_Free_Trader/roleplays\roleplay_9030_12_What_happens_in_space_stays_in_space.json
# Data saved.
# Getting roleplay 8603 for campaign 1660.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/8603
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/1660_Uncharted_Worlds_Free_Trader/roleplays\roleplay_8603_11_Into_the_Black_.json
# Data saved.
# Getting roleplay 7985 for campaign 1660.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/7985
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/1660_Uncharted_Worlds_Free_Trader/roleplays\roleplay_7985_10a_Meeting_Jake_in_the_Concourse.json
# Data saved.
# Getting roleplay 7986 for campaign 1660.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/7986
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/1660_Uncharted_Worlds_Free_Trader/roleplays\roleplay_7986_10b_Rescuing_Hostages_from_the_Tsume.json
# Data saved.
# Getting roleplay 7486 for campaign 1660.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/7486
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/1660_Uncharted_Worlds_Free_Trader/roleplays\roleplay_7486_09_Prosperitas_New_Mission.json
# Data saved.
# Getting roleplay 6963 for campaign 1660.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/6963
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/1660_Uncharted_Worlds_Free_Trader/roleplays\roleplay_6963_08a_Hesperida_Reunification_Edmund_Barrus_Grem_Lir.json
# Data saved.
# Getting roleplay 6964 for campaign 1660.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/6964
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/1660_Uncharted_Worlds_Free_Trader/roleplays\roleplay_6964_08b_Prosperitas_onboard_Sunny.json
# Data saved.
# Getting roleplay 5506 for campaign 1660.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/5506
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/1660_Uncharted_Worlds_Free_Trader/roleplays\roleplay_5506_06a_Holiday_in_Hesperida_Grem_Lirael.json
# Data saved.
# Getting roleplay 6075 for campaign 1660.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/6075
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/1660_Uncharted_Worlds_Free_Trader/roleplays\roleplay_6075_07b_Hesperida_Heaven_Edmund_Sunny_Barrus.json
# Data saved.
# Getting roleplay 6004 for campaign 1660.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/6004
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/1660_Uncharted_Worlds_Free_Trader/roleplays\roleplay_6004_06c_OOC_elaborating_factions.json
# Data saved.
# Getting roleplay 5648 for campaign 1660.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/5648
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/1660_Uncharted_Worlds_Free_Trader/roleplays\roleplay_5648_06b_Holiday_in_HesperidaEdmund_Sunny.json
# Data saved.
# Getting roleplay 3612 for campaign 1660.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/3612
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/1660_Uncharted_Worlds_Free_Trader/roleplays\roleplay_3612_02.5_Night_on_Kiril_and_a_conference..json
# Data saved.
# Getting roleplay 3308 for campaign 1660.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/3308
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/1660_Uncharted_Worlds_Free_Trader/roleplays\roleplay_3308_02_Xiomara_and_the_Pirates.json
# Data saved.
# Getting roleplay 3244 for campaign 1660.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/3244
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/1660_Uncharted_Worlds_Free_Trader/roleplays\roleplay_3244_01.5_Decisions_above_Kiril.json
# Data saved.
# Getting roleplay 3135 for campaign 1660.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/3135
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/1660_Uncharted_Worlds_Free_Trader/roleplays\roleplay_3135_01_Kiril_Delivery.json
# Data saved.
# Getting roleplay 3873 for campaign 1660.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/3873
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/1660_Uncharted_Worlds_Free_Trader/roleplays\roleplay_3873_03_Intrigue_in_Bolshoygorod.json
# Data saved.
# Getting roleplay 5165 for campaign 1660.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/5165
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/1660_Uncharted_Worlds_Free_Trader/roleplays\roleplay_5165_05_Beyond_Kiril.json
# Data saved.
# Getting roleplay 4639 for campaign 1660.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/4639
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/1660_Uncharted_Worlds_Free_Trader/roleplays\roleplay_4639_04_A_Funny_Thing_Happened_on_the_Way_to_the_Launchpad.json
# Data saved.
# Roleplays Complete
# Getting discussion 7804 for campaign 1660
# Request URL is https://www.tavern-keeper.com/api_v0/campaigns/1660/discussions/7804
# export path is: export_data_20250427_194352/1660_Uncharted_Worlds_Free_Trader/discussions\discussion_7804_How_is_everyone_these_days_.json
# Data saved.
# Getting discussion 5136 for campaign 1660
# Request URL is https://www.tavern-keeper.com/api_v0/campaigns/1660/discussions/5136
# export path is: export_data_20250427_194352/1660_Uncharted_Worlds_Free_Trader/discussions\discussion_5136_New_Character_Discussion.json
# Data saved.
# Getting discussion 5132 for campaign 1660
# Request URL is https://www.tavern-keeper.com/api_v0/campaigns/1660/discussions/5132
# export path is: export_data_20250427_194352/1660_Uncharted_Worlds_Free_Trader/discussions\discussion_5132_Instituting_XP_for_6_rolls.json
# Data saved.
# Getting discussion 2846 for campaign 1660
# Request URL is https://www.tavern-keeper.com/api_v0/campaigns/1660/discussions/2846
# export path is: export_data_20250427_194352/1660_Uncharted_Worlds_Free_Trader/discussions\discussion_2846_Current_XP_Triggers.json
# Data saved.
# Getting discussion 3699 for campaign 1660
# Request URL is https://www.tavern-keeper.com/api_v0/campaigns/1660/discussions/3699
# export path is: export_data_20250427_194352/1660_Uncharted_Worlds_Free_Trader/discussions\discussion_3699_Sick_Delay.json
# Data saved.
# Getting discussion 3532 for campaign 1660
# Request URL is https://www.tavern-keeper.com/api_v0/campaigns/1660/discussions/3532
# export path is: export_data_20250427_194352/1660_Uncharted_Worlds_Free_Trader/discussions\discussion_3532_20170114_Adding_a_new_PC_kai91_.json
# Data saved.
# Getting discussion 2811 for campaign 1660
# Request URL is https://www.tavern-keeper.com/api_v0/campaigns/1660/discussions/2811
# export path is: export_data_20250427_194352/1660_Uncharted_Worlds_Free_Trader/discussions\discussion_2811_Startup_4_Character_Creation.json
# Data saved.
# Getting discussion 2843 for campaign 1660
# Request URL is https://www.tavern-keeper.com/api_v0/campaigns/1660/discussions/2843
# export path is: export_data_20250427_194352/1660_Uncharted_Worlds_Free_Trader/discussions\discussion_2843_Chat_Channel_.json
# Data saved.
# Getting discussion 2827 for campaign 1660
# Request URL is https://www.tavern-keeper.com/api_v0/campaigns/1660/discussions/2827
# export path is: export_data_20250427_194352/1660_Uncharted_Worlds_Free_Trader/discussions\discussion_2827_Startup_5_Some_Technology_Questions.json
# Data saved.
# Getting discussion 2798 for campaign 1660
# Request URL is https://www.tavern-keeper.com/api_v0/campaigns/1660/discussions/2798
# export path is: export_data_20250427_194352/1660_Uncharted_Worlds_Free_Trader/discussions\discussion_2798_Startup_1_Let_s_Create_Factions_.json
# Data saved.
# Getting discussion 2803 for campaign 1660
# Request URL is https://www.tavern-keeper.com/api_v0/campaigns/1660/discussions/2803
# export path is: export_data_20250427_194352/1660_Uncharted_Worlds_Free_Trader/discussions\discussion_2803_Startup_2_Game_tone_and_character_interaction_preferences.json
# Data saved.
# Getting discussion 2804 for campaign 1660
# Request URL is https://www.tavern-keeper.com/api_v0/campaigns/1660/discussions/2804
# export path is: export_data_20250427_194352/1660_Uncharted_Worlds_Free_Trader/discussions\discussion_2804_Startup_3_Setting_and_Plot_choices.json
# Data saved.
# Getting discussion 2794 for campaign 1660
# Request URL is https://www.tavern-keeper.com/api_v0/campaigns/1660/discussions/2794
# export path is: export_data_20250427_194352/1660_Uncharted_Worlds_Free_Trader/discussions\discussion_2794_Player_Roster.json
# Data saved.
# Campaign 1660 complete
# Fetching roleplay list for campaign 5396.
# export path is: export_data_20250427_194352/5396_Hit_the_Streets_Defend_the_Block/roleplays\index_roleplay_list_campaign_5396_Hit_the_Streets_Defend_the_Block.json
# Data saved.
# Fetching discussion list for campaign 5396.
# export path is: export_data_20250427_194352/5396_Hit_the_Streets_Defend_the_Block/discussions\index_discussion_list_campaign_5396_Hit_the_Streets_Defend_the_Block.json
# Data saved.
# Getting roleplay 11396 for campaign 5396.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/11396
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/5396_Hit_the_Streets_Defend_the_Block/roleplays\roleplay_11396_What_s_Spooking_Jaxx_L_1.5_N_1.4_.json
# Data saved.
# Getting roleplay 11395 for campaign 5396.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/11395
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/5396_Hit_the_Streets_Defend_the_Block/roleplays\roleplay_11395_Marble_Murder_Cap_1.5_RJ_1.5_.json
# Data saved.
# Getting roleplay 11393 for campaign 5396.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/11393
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/5396_Hit_the_Streets_Defend_the_Block/roleplays\roleplay_11393_A_Chat_with_Britt_S_1.4_.json
# Data saved.
# Getting roleplay 10866 for campaign 5396.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/10866
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/5396_Hit_the_Streets_Defend_the_Block/roleplays\roleplay_10866_Practice_Makes...L_1.2_N_1.3_.json
# Data saved.
# Getting roleplay 11231 for campaign 5396.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/11231
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/5396_Hit_the_Streets_Defend_the_Block/roleplays\roleplay_11231_Wabbit_Hunting_Cap_1.4_Dr.B_1.4_L_1.4_RJ_1.4_S_1.3_.json
# Data saved.
# Getting roleplay 10865 for campaign 5396.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/10865
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/5396_Hit_the_Streets_Defend_the_Block/roleplays\roleplay_10865_The_Marble_Thing_RJ_1.3_S_1.2_.json
# Data saved.
# Getting roleplay 10968 for campaign 5396.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/10968
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/5396_Hit_the_Streets_Defend_the_Block/roleplays\roleplay_10968_Teacher_s_Lounge_and_Such_L_1.3_.json
# Data saved.
# Getting roleplay 10952 for campaign 5396.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/10952
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/5396_Hit_the_Streets_Defend_the_Block/roleplays\roleplay_10952_Tending_Bar_Cap_1.3_.json
# Data saved.
# Getting roleplay 11061 for campaign 5396.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/11061
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/5396_Hit_the_Streets_Defend_the_Block/roleplays\roleplay_11061_Cap_and_Salman_Phone_Call_Cap_1.3b_S_1.2b_.json
# Data saved.
# Getting roleplay 10938 for campaign 5396.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/10938
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/5396_Hit_the_Streets_Defend_the_Block/roleplays\roleplay_10938_Given_the_Choice_Dr.B_1.3_.json
# Data saved.
# Getting roleplay 10817 for campaign 5396.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/10817
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/5396_Hit_the_Streets_Defend_the_Block/roleplays\roleplay_10817_Read_a_Book_Save_a_Life_Cap_1.2_Dr.B_1.2_.json
# Data saved.
# Getting roleplay 10779 for campaign 5396.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/10779
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/5396_Hit_the_Streets_Defend_the_Block/roleplays\roleplay_10779_Schschschoolin_N_1.2_.json
# Data saved.
# Getting roleplay 10780 for campaign 5396.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/10780
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/5396_Hit_the_Streets_Defend_the_Block/roleplays\roleplay_10780_A_Special_Auto_Repair_RJ_1.2_.json
# Data saved.
# Getting roleplay 10766 for campaign 5396.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/10766
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/5396_Hit_the_Streets_Defend_the_Block/roleplays\roleplay_10766_CivicMinded_L_1.1_S_1.1_.json
# Data saved.
# Getting roleplay 10764 for campaign 5396.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/10764
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/5396_Hit_the_Streets_Defend_the_Block/roleplays\roleplay_10764_Sunny_Side_Up_Cap_1.1_Dr.B_1.1_.json
# Data saved.
# Getting roleplay 10762 for campaign 5396.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/10762
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/5396_Hit_the_Streets_Defend_the_Block/roleplays\roleplay_10762_Morning_Rush_N_1.1_RJ_1.1_.json
# Data saved.
# Roleplays Complete
# Getting discussion 8744 for campaign 5396
# Request URL is https://www.tavern-keeper.com/api_v0/campaigns/5396/discussions/8744
# export path is: export_data_20250427_194352/5396_Hit_the_Streets_Defend_the_Block/discussions\discussion_8744_Neighborhood_Creation_Stuff.json
# Data saved.
# Campaign 5396 complete
# Fetching roleplay list for campaign 5124.
# export path is: export_data_20250427_194352/5124_Scum_and_Villainy_Procyon_Sector_Blues/roleplays\index_roleplay_list_campaign_5124_Scum_and_Villainy_Procyon_Sector_Blues.json
# Data saved.
# Fetching discussion list for campaign 5124.
# export path is: export_data_20250427_194352/5124_Scum_and_Villainy_Procyon_Sector_Blues/discussions\index_discussion_list_campaign_5124_Scum_and_Villainy_Procyon_Sector_Blues.json
# Data saved.
# Getting roleplay 10250 for campaign 5124.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/10250
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/5124_Scum_and_Villainy_Procyon_Sector_Blues/roleplays\roleplay_10250_S1_E1_Easy_Money_Wasn_t_It_.json
# Data saved.
# Roleplays Complete
# Getting discussion 8303 for campaign 5124
# Request URL is https://www.tavern-keeper.com/api_v0/campaigns/5124/discussions/8303
# export path is: export_data_20250427_194352/5124_Scum_and_Villainy_Procyon_Sector_Blues/discussions\discussion_8303_The_EverLovin_OOC_Thread.json
# Data saved.
# Getting discussion 8297 for campaign 5124
# Request URL is https://www.tavern-keeper.com/api_v0/campaigns/5124/discussions/8297
# export path is: export_data_20250427_194352/5124_Scum_and_Villainy_Procyon_Sector_Blues/discussions\discussion_8297_Getting_Started_.json
# Data saved.
# Getting discussion 8319 for campaign 5124
# Request URL is https://www.tavern-keeper.com/api_v0/campaigns/5124/discussions/8319
# export path is: export_data_20250427_194352/5124_Scum_and_Villainy_Procyon_Sector_Blues/discussions\discussion_8319_Ship_Crew_Creation.json
# Data saved.
# Getting discussion 8316 for campaign 5124
# Request URL is https://www.tavern-keeper.com/api_v0/campaigns/5124/discussions/8316
# export path is: export_data_20250427_194352/5124_Scum_and_Villainy_Procyon_Sector_Blues/discussions\discussion_8316_Connections.json
# Data saved.
# Campaign 5124 complete
# Fetching roleplay list for campaign 4561.
# export path is: export_data_20250427_194352/4561_Masks_Heroism_Bad_Lunch_and_Infidelity/roleplays\index_roleplay_list_campaign_4561_Masks_Heroism_Bad_Lunch_and_Infidelity.json
# Data saved.
# Fetching discussion list for campaign 4561.
# export path is: export_data_20250427_194352/4561_Masks_Heroism_Bad_Lunch_and_Infidelity/discussions\index_discussion_list_campaign_4561_Masks_Heroism_Bad_Lunch_and_Infidelity.json
# Data saved.
# Getting roleplay 10717 for campaign 4561.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/10717
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/4561_Masks_Heroism_Bad_Lunch_and_Infidelity/roleplays\roleplay_10717_Issue_2_Valkyrie_in_Admin_Val_2.1_.json
# Data saved.
# Getting roleplay 10874 for campaign 4561.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/10874
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/4561_Masks_Heroism_Bad_Lunch_and_Infidelity/roleplays\roleplay_10874_Issue_2_Meadow_in_Counselling_Minerva_2.1_.json
# Data saved.
# Getting roleplay 10875 for campaign 4561.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/10875
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/4561_Masks_Heroism_Bad_Lunch_and_Infidelity/roleplays\roleplay_10875_Issue_2_Nemo_in_Trouble.Nemo_2.1_.json
# Data saved.
# Getting roleplay 10873 for campaign 4561.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/10873
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/4561_Masks_Heroism_Bad_Lunch_and_Infidelity/roleplays\roleplay_10873_Issue_2_Wolfman_at_the_Gym_Wolf_2.1_.json
# Data saved.
# Getting roleplay 10696 for campaign 4561.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/10696
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/4561_Masks_Heroism_Bad_Lunch_and_Infidelity/roleplays\roleplay_10696_Issue_1_End_of_Session.json
# Data saved.
# Getting roleplay 9782 for campaign 4561.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/9782
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/4561_Masks_Heroism_Bad_Lunch_and_Infidelity/roleplays\roleplay_9782_Issue_1_Have_a_little_class_Min_1.1_Wolf_1.1_Zan_1.1_Val_1.2_Nem_1.2_.json
# Data saved.
# Getting roleplay 9765 for campaign 4561.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/9765
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/4561_Masks_Heroism_Bad_Lunch_and_Infidelity/roleplays\roleplay_9765_Issue_1_Home_to_Mother.Val_Nemo_1.1_.json
# Data saved.
# Getting roleplay 9308 for campaign 4561.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/9308
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/4561_Masks_Heroism_Bad_Lunch_and_Infidelity/roleplays\roleplay_9308_Issue_1_The_Entertainment_Has_Arrived_All_1.0_.json
# Data saved.
# Roleplays Complete
# Getting discussion 8721 for campaign 4561
# Request URL is https://www.tavern-keeper.com/api_v0/campaigns/4561/discussions/8721
# export path is: export_data_20250427_194352/4561_Masks_Heroism_Bad_Lunch_and_Infidelity/discussions\discussion_8721_Current_Team_Pool_3.json
# Data saved.
# Getting discussion 7489 for campaign 4561
# Request URL is https://www.tavern-keeper.com/api_v0/campaigns/4561/discussions/7489
# export path is: export_data_20250427_194352/4561_Masks_Heroism_Bad_Lunch_and_Infidelity/discussions\discussion_7489_Back_Channel_.json
# Data saved.
# Getting discussion 7531 for campaign 4561
# Request URL is https://www.tavern-keeper.com/api_v0/campaigns/4561/discussions/7531
# export path is: export_data_20250427_194352/4561_Masks_Heroism_Bad_Lunch_and_Infidelity/discussions\discussion_7531_When_our_team_first_came_together..json
# Data saved.
# Getting discussion 7532 for campaign 4561
# Request URL is https://www.tavern-keeper.com/api_v0/campaigns/4561/discussions/7532
# export path is: export_data_20250427_194352/4561_Masks_Heroism_Bad_Lunch_and_Infidelity/discussions\discussion_7532_Character_Introductions.json
# Data saved.
# Getting discussion 7487 for campaign 4561
# Request URL is https://www.tavern-keeper.com/api_v0/campaigns/4561/discussions/7487
# export path is: export_data_20250427_194352/4561_Masks_Heroism_Bad_Lunch_and_Infidelity/discussions\discussion_7487_Character_Concepts.json
# Data saved.
# Getting discussion 7491 for campaign 4561
# Request URL is https://www.tavern-keeper.com/api_v0/campaigns/4561/discussions/7491
# export path is: export_data_20250427_194352/4561_Masks_Heroism_Bad_Lunch_and_Infidelity/discussions\discussion_7491_Post_Style_Voice_and_Formatting.json
# Data saved.
# Getting discussion 7492 for campaign 4561
# Request URL is https://www.tavern-keeper.com/api_v0/campaigns/4561/discussions/7492
# export path is: export_data_20250427_194352/4561_Masks_Heroism_Bad_Lunch_and_Infidelity/discussions\discussion_7492_Backstory_some_collaborative_world_building_.json
# Data saved.
# Getting discussion 7514 for campaign 4561
# Request URL is https://www.tavern-keeper.com/api_v0/campaigns/4561/discussions/7514
# export path is: export_data_20250427_194352/4561_Masks_Heroism_Bad_Lunch_and_Infidelity/discussions\discussion_7514_Team_Name.json
# Data saved.
# Getting discussion 7488 for campaign 4561
# Request URL is https://www.tavern-keeper.com/api_v0/campaigns/4561/discussions/7488
# export path is: export_data_20250427_194352/4561_Masks_Heroism_Bad_Lunch_and_Infidelity/discussions\discussion_7488_Game_Lengh_Check_in..json
# Data saved.
# Getting discussion 7477 for campaign 4561
# Request URL is https://www.tavern-keeper.com/api_v0/campaigns/4561/discussions/7477
# export path is: export_data_20250427_194352/4561_Masks_Heroism_Bad_Lunch_and_Infidelity/discussions\discussion_7477_Opening_Discussion.json
# Data saved.
# Getting discussion 7490 for campaign 4561
# Request URL is https://www.tavern-keeper.com/api_v0/campaigns/4561/discussions/7490
# export path is: export_data_20250427_194352/4561_Masks_Heroism_Bad_Lunch_and_Infidelity/discussions\discussion_7490_Safety_Lines_and_Veils_Rating.json
# Data saved.
# Campaign 4561 complete
# Fetching roleplay list for campaign 2923.
# export path is: export_data_20250427_194352/2923_Sunset_Hearts/roleplays\index_roleplay_list_campaign_2923_Sunset_Hearts.json
# Data saved.
# Fetching discussion list for campaign 2923.
# export path is: export_data_20250427_194352/2923_Sunset_Hearts/discussions\index_discussion_list_campaign_2923_Sunset_Hearts.json
# Data saved.
# Getting roleplay 6604 for campaign 2923.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/6604
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/2923_Sunset_Hearts/roleplays\roleplay_6604_3_The_Launch_party.json
# Data saved.
# Getting roleplay 6801 for campaign 2923.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/6801
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/2923_Sunset_Hearts/roleplays\roleplay_6801_3.1_Launch_party.The_Moore_Sisters..json
# Data saved.
# Getting roleplay 6472 for campaign 2923.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/6472
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/2923_Sunset_Hearts/roleplays\roleplay_6472_2a_Lunchtime.json
# Data saved.
# Getting roleplay 6575 for campaign 2923.
# Getting Scene Data
# ...
# Request URL is https://www.tavern-keeper.com/api_v0/campaigns/716/discussions/955
# export path is: export_data_20250427_194352/716_Verdant_Valley/discussions\discussion_955_Fiddly_bits.json
# Data saved.
# Getting discussion 940 for campaign 716
# Request URL is https://www.tavern-keeper.com/api_v0/campaigns/716/discussions/940
# export path is: export_data_20250427_194352/716_Verdant_Valley/discussions\discussion_940_Let_s_do_HX_.json
# Data saved.
# Getting discussion 944 for campaign 716
# Request URL is https://www.tavern-keeper.com/api_v0/campaigns/716/discussions/944
# export path is: export_data_20250427_194352/716_Verdant_Valley/discussions\discussion_944_SESSION_ONE_Highlights.json
# Data saved.
# Getting discussion 934 for campaign 716
# Request URL is https://www.tavern-keeper.com/api_v0/campaigns/716/discussions/934
# export path is: export_data_20250427_194352/716_Verdant_Valley/discussions\discussion_934_Who_you_gonna_play_.json
# Data saved.
# Getting discussion 939 for campaign 716
# Request URL is https://www.tavern-keeper.com/api_v0/campaigns/716/discussions/939
# export path is: export_data_20250427_194352/716_Verdant_Valley/discussions\discussion_939_Verdant_Valley_map.json
# Data saved.
# Campaign 716 complete
# Fetching roleplay list for campaign 671.
# export path is: export_data_20250427_194352/671_Urban_Shadows_Chicago/roleplays\index_roleplay_list_campaign_671_Urban_Shadows_Chicago.json
# Data saved.
# Fetching discussion list for campaign 671.
# export path is: export_data_20250427_194352/671_Urban_Shadows_Chicago/discussions\index_discussion_list_campaign_671_Urban_Shadows_Chicago.json
# Data saved.
# Getting roleplay 1073 for campaign 671.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/1073
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/671_Urban_Shadows_Chicago/roleplays\roleplay_1073_Space_Between_Places_Alex_6.3_.json
# Data saved.
# Getting roleplay 1062 for campaign 671.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/1062
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/671_Urban_Shadows_Chicago/roleplays\roleplay_1062_RunIns_Veronica_6.3_.json
# Data saved.
# Getting roleplay 1072 for campaign 671.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/1072
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/671_Urban_Shadows_Chicago/roleplays\roleplay_1072_The_Talents_Kath_6.6_.json
# Data saved.
# Getting roleplay 1022 for campaign 671.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/1022
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/671_Urban_Shadows_Chicago/roleplays\roleplay_1022_Five_O_Clock_Shadows_Alex_6.2_Kath_6.5_.json
# Data saved.
# Getting roleplay 1023 for campaign 671.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/1023
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/671_Urban_Shadows_Chicago/roleplays\roleplay_1023_Forgot_My_Conditioner_Veronica_6.2_.json
# Data saved.
# Getting roleplay 1051 for campaign 671.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/1051
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/671_Urban_Shadows_Chicago/roleplays\roleplay_1051_Long_Walks_Kath_6.6_.json
# Data saved.
# Getting roleplay 1003 for campaign 671.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/1003
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/671_Urban_Shadows_Chicago/roleplays\roleplay_1003_A_Pack_a_Day_Habit_Veronica_6.1_.json
# Data saved.
# Getting roleplay 990 for campaign 671.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/990
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/671_Urban_Shadows_Chicago/roleplays\roleplay_990_Little_Narc_Alex_6.1_Kath_6.4_.json
# Data saved.
# Getting roleplay 1015 for campaign 671.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/1015
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/671_Urban_Shadows_Chicago/roleplays\roleplay_1015_Old_Times_Kath_6.3_.json
# Data saved.
# Getting roleplay 1007 for campaign 671.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/1007
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/671_Urban_Shadows_Chicago/roleplays\roleplay_1007_Heavenly_Kath_6.2_.json
# Data saved.
# Getting roleplay 994 for campaign 671.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/994
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/671_Urban_Shadows_Chicago/roleplays\roleplay_994_Neck_Deep_in_the_Dead_Kath_6.1_.json
# Data saved.
# Getting roleplay 987 for campaign 671.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/987
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/671_Urban_Shadows_Chicago/roleplays\roleplay_987_Session_Six_Opening_ALL_6.0_.json
# Data saved.
# Getting roleplay 972 for campaign 671.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/972
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/671_Urban_Shadows_Chicago/roleplays\roleplay_972_The_Gun_Shop_Kath_5.6_.json
# Data saved.
# Getting roleplay 963 for campaign 671.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/963
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/671_Urban_Shadows_Chicago/roleplays\roleplay_963_New_Ink_Alex_5.9_.json
# Data saved.
# Getting roleplay 964 for campaign 671.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/964
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/671_Urban_Shadows_Chicago/roleplays\roleplay_964_Because_Because_Because_Because_Because....Veronica_5.4_.json
# Data saved.
# Getting roleplay 969 for campaign 671.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/969
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/671_Urban_Shadows_Chicago/roleplays\roleplay_969_The_Root_of_All_Evil_Kath_5.5_.json
# Data saved.
# Getting roleplay 962 for campaign 671.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/962
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/671_Urban_Shadows_Chicago/roleplays\roleplay_962_Her_Own_Pile_of_Problems_Kath_5.4_.json
# Data saved.
# Getting roleplay 932 for campaign 671.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/932
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/671_Urban_Shadows_Chicago/roleplays\roleplay_932_Emergent_Alex_5.8_Kath_5.2_.json
# Data saved.
# Getting roleplay 905 for campaign 671.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/905
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/671_Urban_Shadows_Chicago/roleplays\roleplay_905_Pack_Hunting_Veronica_5.3_.json
# Data saved.
# Getting roleplay 961 for campaign 671.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/961
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/671_Urban_Shadows_Chicago/roleplays\roleplay_961_My_Not_Boyfriend_Kath_5.3_.json
# Data saved.
# Getting roleplay 831 for campaign 671.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/831
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/671_Urban_Shadows_Chicago/roleplays\roleplay_831_Longyearbyen_Alex_5.4_.json
# Data saved.
# Getting roleplay 935 for campaign 671.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/935
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/671_Urban_Shadows_Chicago/roleplays\roleplay_935_Sooth_Kath_5.1_.json
# Data saved.
# Getting roleplay 904 for campaign 671.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/904
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/671_Urban_Shadows_Chicago/roleplays\roleplay_904_Kirsten_Calls_Alex_5.7_.json
# Data saved.
# Getting roleplay 865 for campaign 671.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/865
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/671_Urban_Shadows_Chicago/roleplays\roleplay_865_Arrivals_Alex_5.6_Veronica_5.2_.json
# Data saved.
# Getting roleplay 816 for campaign 671.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/816
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/671_Urban_Shadows_Chicago/roleplays\roleplay_816_Brunch_Veronica_5.1_.json
# Data saved.
# Getting roleplay 860 for campaign 671.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/860
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/671_Urban_Shadows_Chicago/roleplays\roleplay_860_Saying_Goodbyes_Alex_5.5_.json
# Data saved.
# Getting roleplay 815 for campaign 671.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/815
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/671_Urban_Shadows_Chicago/roleplays\roleplay_815_Aftermath_Alex_5.3_.json
# Data saved.
# Getting roleplay 770 for campaign 671.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/770
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/671_Urban_Shadows_Chicago/roleplays\roleplay_770_Some_Hot_Food_Veronica_4.5_.json
# Data saved.
# Getting roleplay 794 for campaign 671.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/794
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/671_Urban_Shadows_Chicago/roleplays\roleplay_794_Mount_Up_Alex_5.2_.json
# Data saved.
# Getting roleplay 783 for campaign 671.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/783
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/671_Urban_Shadows_Chicago/roleplays\roleplay_783_Half_In_Half_Out_Alex_5.1_.json
# Data saved.
# Getting roleplay 766 for campaign 671.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/766
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/671_Urban_Shadows_Chicago/roleplays\roleplay_766_Encroachment_Alex_4.6_.json
# Data saved.
# Getting roleplay 746 for campaign 671.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/746
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/671_Urban_Shadows_Chicago/roleplays\roleplay_746_Meeting_Miss_Bliss_Veronica_4.4_.json
# Data saved.
# Getting roleplay 748 for campaign 671.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/748
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/671_Urban_Shadows_Chicago/roleplays\roleplay_748_Clubbing_Alex_4.5_.json
# Data saved.
# Getting roleplay 736 for campaign 671.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/736
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/671_Urban_Shadows_Chicago/roleplays\roleplay_736_Ends_Meet_Alex_4.4_.json
# Data saved.
# Getting roleplay 719 for campaign 671.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/719
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/671_Urban_Shadows_Chicago/roleplays\roleplay_719_Down_at_the_Lake_Veronica_4.3_.json
# Data saved.
# Getting roleplay 706 for campaign 671.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/706
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/671_Urban_Shadows_Chicago/roleplays\roleplay_706_Return_Alex_4.3_.json
# Data saved.
# Getting roleplay 695 for campaign 671.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/695
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/671_Urban_Shadows_Chicago/roleplays\roleplay_695_It_s_Just_Coffee_right_Veronica_4.2_.json
# Data saved.
# Getting roleplay 689 for campaign 671.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/689
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/671_Urban_Shadows_Chicago/roleplays\roleplay_689_Detroit_Alex_4.2_.json
# Data saved.
# Getting roleplay 685 for campaign 671.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/685
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/671_Urban_Shadows_Chicago/roleplays\roleplay_685_Seek_and...Veronica_4.1_.json
# Data saved.
# Getting roleplay 679 for campaign 671.
# Getting Scene Data
# Request URL is https://www.tavern-keeper.com/api_v0/roleplays/679
# Getting Message Data
# Fetching Comments for Messages
# export path is: export_data_20250427_194352/671_Urban_Shadows_Chicago/roleplays\roleplay_679_Say_My_Name_Say_My_Name_Alex_4.1_.json
# Data saved.
# Roleplays Complete
# Getting discussion 1273 for campaign 671
# Request URL is https://www.tavern-keeper.com/api_v0/campaigns/671/discussions/1273
# export path is: export_data_20250427_194352/671_Urban_Shadows_Chicago/discussions\discussion_1273_Ending_IT.json
# Data saved.
# Getting discussion 1261 for campaign 671
# Request URL is https://www.tavern-keeper.com/api_v0/campaigns/671/discussions/1261
# export path is: export_data_20250427_194352/671_Urban_Shadows_Chicago/discussions\discussion_1261_Weeklong_break.json
# Data saved.
# Getting discussion 1191 for campaign 671
# Request URL is https://www.tavern-keeper.com/api_v0/campaigns/671/discussions/1191
# export path is: export_data_20250427_194352/671_Urban_Shadows_Chicago/discussions\discussion_1191_Debts_Tracking.json
# Data saved.
# Getting discussion 1193 for campaign 671
# Request URL is https://www.tavern-keeper.com/api_v0/campaigns/671/discussions/1193
# export path is: export_data_20250427_194352/671_Urban_Shadows_Chicago/discussions\discussion_1193_Oracle_Fixes.json
# Data saved.
# Getting discussion 861 for campaign 671
# Request URL is https://www.tavern-keeper.com/api_v0/campaigns/671/discussions/861
# export path is: export_data_20250427_194352/671_Urban_Shadows_Chicago/discussions\discussion_861_Session_4_Beginning.json
# Data saved.
# Campaign 671 complete
# All campaigns downloaded. Process complete
# [(1660, 'Uncharted Worlds: Free Trader'),
#  (5396, 'Hit the Streets: Defend the Block'),
#  (5124, 'Scum and Villainy: Procyon Sector Blues'),
#  (4561, 'Masks: Heroism, Bad Lunch, and Infidelity'),
#  (2923, 'Sunset Hearts'),
#  (4424, 'Urban Shadows: Shadow Queens'),
#  (3345, 'Jagged'),
#  (2862, "Masks - Hudson's Bay"),
#  (1967, "Monsterhearts 2 - Hudson's Bay"),
#  (1752, 'MotW: Monuments and Shadows'),
#  (762, 'Sorcerer - The Secret Books'),
#  (716, 'Verdant Valley'),
#  (671, 'Urban Shadows Chicago')]
